# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
CURR_DIR = os.getcwd()

MAIN_DIR = '.'
if os.path.basename(CURR_DIR)!="Project_Work22.04":
    os.chdir("..")
DATA_DIR = os.path.join(MAIN_DIR,"Data/DataWD0011-399")
FITS_DIR = os.path.join(MAIN_DIR,"Fits")
FIG_DIR = os.path.join(MAIN_DIR,"Project-Files/Figures/Plots/")
# FIG_DIR

# %%
data_files = sorted(glob.glob(DATA_DIR + "/**/*.csv", recursive=True))
data_files
# Out:
# ['./Data/DataWD0011-399/Gaia-WD0011-399.csv',
#  './Data/DataWD0011-399/Simbad-WD0011-399.csv',
#  './Data/DataWD0011-399/WD0011-399_AKARI.csv',
#  './Data/DataWD0011-399/WD0011-399_IRAS.csv',
#  './Data/DataWD0011-399/WD0011-399_WISE.csv']

# %%
# data = pd.read_csv(data_files[6])
# data

# %%
data_akari = pd.read_csv(data_files[2])
data_akari
# Out:
#           F90   x   y        RA        DEC      F140  x1  y1       RA1  \
# 0    0.762714   1  30  3.856797 -39.115224  3.066137   1  30  3.856797
# 1    1.286675   2  30  3.849064 -39.115231  2.553307   2  30  3.849064
# 2    1.758307   3  30  3.841331 -39.115238  2.927438   3  30  3.841331
# 3    1.834949   4  30  3.833598 -39.115244  3.635061   4  30  3.833598
# 4    1.411721   5  30  3.825865 -39.115250  4.300227   5  30  3.825865
# ..        ...  ..  ..       ...        ...       ...  ..  ..       ...
# 895  2.257539  26   1  3.663267 -39.289249  3.044896  26   1  3.663267
# 896  2.256902  27   1  3.655515 -39.289244  3.667239  27   1  3.655515
# 897  1.711771  28   1  3.647762 -39.289238  3.003741  28   1  3.647762
# 898  1.685992  29   1  3.640010 -39.289231  2.440917  29   1  3.640010
# 899  1.637724  30   1  3.632258 -39.289224  1.952804  30   1  3.632258
#
#           DEC1
# 0   -39.115224
# 1   -39.115231
# 2   -39.115238
# 3   -39.115244
# 4   -39.115250
# ..         ...
# ...

# %%
data_iras = pd.read_csv(data_files[3])
data_iras
# Out:
#           F60   x   y        RA        DEC      F100  x1  y1       RA1  \
# 0    0.632244   1  25  4.106359 -38.961595  1.756098   1  25  4.106359
# 1    0.646267   2  25  4.080639 -38.961660  1.764143   2  25  4.080639
# 2    0.713218   3  25  4.054918 -38.961719  1.685077   3  25  4.054918
# 3    0.640321   4  25  4.029197 -38.961773  1.639124   4  25  4.029197
# 4    0.640321   5  25  4.003477 -38.961821  1.639124   5  25  4.003477
# ..        ...  ..  ..       ...        ...       ...  ..  ..       ...
# 620  0.637537  21   1  3.590529 -39.441815  1.567818  21   1  3.590529
# 621  0.557569  22   1  3.564632 -39.441766  1.552701  22   1  3.564632
# 622  0.557569  23   1  3.538735 -39.441711  1.552701  23   1  3.538735
# 623  0.544347  24   1  3.512838 -39.441651  1.507985  24   1  3.512838
# 624  0.532718  25   1  3.486941 -39.441585  1.481793  25   1  3.486941
#
#           DEC1
# 0   -38.961595
# 1   -38.961660
# 2   -38.961719
# 3   -38.961773
# 4   -38.961821
# ..         ...
# ...

# %%
data_wise = pd.read_csv(data_files[4])
data_wise
# Out:
#             F12   x   y        RA        DEC         F22  x1  y1       RA1  \
# 0    425.113007   1  30  3.806996 -39.153928  127.219253   1  30  3.806996
# 1    424.051025   2  30  3.802697 -39.153930  127.189728   2  30  3.802697
# 2    423.813385   3  30  3.798399 -39.153932  127.183258   3  30  3.798399
# 3    424.799988   4  30  3.794100 -39.153934  127.265892   4  30  3.794100
# 4    424.565796   5  30  3.789802 -39.153936  127.223099   5  30  3.789802
# ..          ...  ..  ..       ...        ...         ...  ..  ..       ...
# 895  424.526001  26   1  3.699470 -39.250602  127.229324  26   1  3.699470
# 896  425.028381  27   1  3.695165 -39.250601  127.294769  27   1  3.695165
# 897  424.715057  28   1  3.690861 -39.250599  127.293732  28   1  3.690861
# 898  425.010651  29   1  3.686556 -39.250597  127.313255  29   1  3.686556
# 899  424.744293  30   1  3.682252 -39.250594  127.241157  30   1  3.682252
#
#           DEC1
# 0   -39.153928
# 1   -39.153930
# 2   -39.153932
# ...

# %%
min(data_akari.RA), max(data_akari.RA), min(data_akari.DEC), max(data_akari.DEC)
# Out:
# (3.632257846, 3.857075488, -39.28927765, -39.11522414)

# %%
np.mean(data_iras.F60), np.mean(data_iras.F100), np.mean(data_akari.F90), np.mean(data_akari.F140), np.mean(data_wise.F12), np.mean(data_wise.F22)
# Out:
# (1.7918392460702401,
#  4.050292485673601,
#  11.266067651386887,
#  16.292476929153334,
#  435.51174533355555,
#  128.53798446666667)

# %%
def flux_scatter(data1, data2, label='Average', fontsize=28):
    plt.scatter(data1, data2, color='red', s=150)
    plt.plot(data1, data2, '-o', linewidth=4)
    plt.xlabel('Wavelength ($\mu$m)', fontweight = 'bold', fontsize=fontsize)
    plt.ylabel(label+'Flux (MJy sr$^{-1}$)', fontweight = 'bold', fontsize=fontsize)
    plt.xticks(fontsize=fontsize, color = 'k')
    plt.yticks(fontsize=fontsize,color='k')

# %%
flux_avg = [435.51, 128.54, 1.79, 11.27, 4.05, 16.29]

flux_min = [440.62, 128.22, 0.738, 12.31, 2.39,  22.04]
flux_max = [ 705.20, 166.33, 172.22, 34.66, 47.44, 129.94]
wavelength = [12, 22, 60, 90, 100, 140]

plt.figure(figsize=(40,10))
plt.subplot(131)
flux_scatter(wavelength, flux_min, label='Minimum')

plt.subplot(132)
flux_scatter(wavelength, flux_max, label='Maximum')

plt.subplot(133)
flux_scatter(wavelength, flux_avg)

# plt.savefig(FIG_DIR+"flux-wavelength.png")

# %%
np.mean(data_iras.RA), np.mean(data_iras.DEC)
# Out:
# (3.7977083333375994, -39.201851950752)

# %%
# min(data_wise.RA), max(data_wise.RA), min(data_wise.DEC), max(data_wise.DEC)

# %%
print("IRIS60:", min(data_iras.F60), max(data_iras.F60))
print("IRIS100:", min(data_iras.F100), max(data_iras.F100))

print("AKARI90:", min(data_akari.F90), max(data_akari.F90))
print("AKARI140:", min(data_akari.F140), max(data_akari.F140))

print("WISE12:", min(data_wise.F12), max(data_wise.F12))
print("WISE22:", min(data_wise.F22), max(data_wise.F22))
# Out:
# IRIS60: 0.4882417917 34.66217422
# IRIS100: 1.377496958 47.44547653
# AKARI90: 0.708106935 172.2238159
# AKARI140: 1.780066252 129.9443054
# WISE12: 423.722168 705.2015381
# WISE22: 127.105957 166.3269958

# %%
# def nearest(array, value):
#     array = np.asarray(array)
#     idx = (np.abs(array-value)).argmin()
#     return array[idx]

# %% [markdown]
# ## TEMPERATURE CALCULATION

# %%
# Temp = -96/(np.log((data_iras.F60/data_iras.F100)*0.6**5))
# data_iras['Temp'] = Temp
# count = 0
# for i in range (len(data_iras.Temp)):
#     if data_iras.Temp[i]<=0:
#         count +=1
# count

# %%
data_akari = data_akari[data_akari.F90>12]
data_akari = data_akari[data_akari.F140>22]

data_iras = data_iras[data_iras.F60>0.7]
data_iras = data_iras[data_iras.F100>2.9]

data_wise = data_wise[data_wise.F12>440]
data_wise = data_wise[data_wise.F22>128]

# %%
Temp1 = -57/(np.log((data_akari.F90/data_akari.F140)*0.6**5))
data_akari['Temp'] = Temp1
data_akari
# Out:
#            F90   x   y        RA        DEC       F140  x1  y1       RA1  \
# 295  13.075224  26  21  3.663406 -39.169250  33.491352  26  21  3.663406
# 296  12.227504  27  21  3.655667 -39.169244  30.531187  27  21  3.655667
# 297  12.729028  28  21  3.647928 -39.169238  24.757790  28  21  3.647928
# 298  14.064187  29  21  3.640189 -39.169231  23.709055  29  21  3.640189
# 313  15.772798  14  20  3.756276 -39.175277  26.957417  14  20  3.756276
# ..         ...  ..  ..       ...        ...        ...  ..  ..       ...
# 608  14.514862   9  10  3.795018 -39.235267  22.321301   9  10  3.795018
# 609  15.492190  10  10  3.787272 -39.235270  25.574257  10  10  3.787272
# 610  17.033474  11  10  3.779525 -39.235273  29.241749  11  10  3.779525
# 611  15.432299  12  10  3.771779 -39.235275  22.120295  12  10  3.771779
# 640  13.432501  11   9  3.779528 -39.241273  22.716867  11   9  3.779528
#
#           DEC1       Temp          Mass
# 295 -39.169250  16.310430  4.871943e+27
# ...

# %%
Temp1 = -96/(np.log((data_iras.F60/data_iras.F100)*0.6**5))
data_iras['Temp'] = Temp1
data_iras
# Out:
#           F60   x   y        RA        DEC      F100  x1  y1       RA1  \
# 192  1.194548  18  18  3.668847 -39.101929  3.141887  18  18  3.668847
# 193  1.078788  19  18  3.643075 -39.101898  3.051645  19  18  3.643075
# 194  0.855018  20  18  3.617303 -39.101861  2.966736  20  18  3.617303
# 195  0.855018  21  18  3.591530 -39.101819  2.966736  21  18  3.591530
# 212  1.229548  13  17  3.797708 -39.122000  3.132796  13  17  3.797708
# ..        ...  ..  ..       ...        ...       ...  ..  ..       ...
# 436  1.440887  12   8  3.823554 -39.301997  3.084902  12   8  3.823554
# 454  0.780115   5   7  4.004533 -39.321817  3.510128   5   7  4.004533
# 455  1.050505   6   7  3.978680 -39.321860  3.362559   6   7  3.978680
# 456  1.050505   7   7  3.952827 -39.321897  3.362559   7   7  3.952827
# 457  1.020826   8   7  3.926974 -39.321928  2.930289   8   7  3.926974
#
#           DEC1       Temp          Mass
# 192 -39.101929  27.263561  1.656916e+28
# ...

# %%
Temp1 = -545.13/(np.log((data_wise.F12/data_wise.F22)*0.6**5))
data_wise['Temp'] = Temp1
data_wise
# Out:
#             F12   x   y        RA        DEC         F22  x1  y1       RA1  \
# 267  440.623566  28  22  3.690914 -39.180599  128.408096  28  22  3.690914
# 291  443.190643  22  21  3.716714 -39.183941  128.551559  22  21  3.716714
# 292  441.797485  23  21  3.712414 -39.183940  128.434952  23  21  3.712414
# 293  441.361511  24  21  3.708113 -39.183939  128.430389  24  21  3.708113
# 294  442.138214  25  21  3.703813 -39.183937  128.541367  25  21  3.703813
# ..          ...  ..  ..       ...        ...         ...  ..  ..       ...
# 610  442.910309  11  10  3.764029 -39.220610  128.983460  11  10  3.764029
# 611  449.780212  12  10  3.759726 -39.220610  129.860474  12  10  3.759726
# 612  451.960785  13  10  3.755423 -39.220611  130.636871  13  10  3.755423
# 613  446.044311  14  10  3.751121 -39.220611  130.485596  14  10  3.751121
# 631  442.926605   2   9  3.802755 -39.223930  128.425705   2   9  3.802755
#
#           DEC1        Temp          Mass
# ...

# %%
print("IRAS Temp:")
print('Tmax:',np.max(data_iras.Temp),'offset:', (np.max(data_iras.Temp)-np.mean(data_iras.Temp))/2)  #max error value = (Tmax-Tavg)/2
print('Tmin:',np.min(data_iras.Temp),'offset:', (np.mean(data_iras.Temp)-np.min(data_iras.Temp))/2)  #max error value = (Tavg-Tmin)/2
print('Tavg:',np.mean(data_iras.Temp),'offset:', np.std(data_iras.Temp)/np.sqrt(len(data_iras.Temp))) #avg error value = SE = sd/sqrt(n)
# Out:
# IRAS Temp:
# Tmax: 36.82251433195769 offset: 4.300051789219156
# Tmin: 23.592021469720347 offset: 2.3151946418995166
# Tavg: 28.22241075351938 offset: 0.17876486584453447

# %%
print("AKARI Temp:")
print('Tmax:',np.max(data_akari.Temp),'offset:', (np.max(data_akari.Temp)-np.mean(data_akari.Temp))/2)  #max error value = (Tmax-Tavg)/2
print('Tmin:',np.min(data_akari.Temp),'offset:', (np.mean(data_akari.Temp)-np.min(data_akari.Temp))/2)  #max error value = (Tavg-Tmin)/2
print('Tavg:',np.mean(data_akari.Temp),'offset:', np.std(data_akari.Temp)/np.sqrt(len(data_akari.Temp))) #avg error value = SE = sd/sqrt(n)
# Out:
# AKARI Temp:
# Tmax: 26.36959462650522 offset: 3.5574611842630315
# Tmin: 16.310430450968635 offset: 1.4721209035052603
# Tavg: 19.254672257979156 offset: 0.14935171486978963

# %%
print("WISE Temp:")
print('Tmax:',np.max(data_wise.Temp),'offset:', (np.max(data_wise.Temp)-np.mean(data_wise.Temp))/2)  #max error value = (Tmax-Tavg)/2
print('Tmin:',np.min(data_wise.Temp),'offset:', (np.mean(data_wise.Temp)-np.min(data_wise.Temp))/2)  #max error value = (Tavg-Tmin)/2
print('Tavg:',np.mean(data_wise.Temp),'offset:', np.std(data_wise.Temp)/np.sqrt(len(data_wise.Temp))) #avg error value = SE = sd/sqrt(n)
# Out:
# WISE Temp:
# Tmax: 492.84336508718275 offset: 34.49262278918465
# Tmin: 407.05112135925015 offset: 8.40349907478165
# Tavg: 423.85811950881345 offset: 1.4869438269566126

# %% [markdown]
# ## SCATTER PLOT

# %%
def scatter(data1, data2):
    coeff = np.polyfit(data1, data2, deg=1)
    p = np.poly1d(coeff)
    y = p(data1)
    plt.plot(data1, y, label='Straight Line Fit', lw=3, color='black')
    plt.scatter(data1, data2, color='m', label='data')
    plt.legend()

# %%
# scatter(wavelength, flux_avg)

# %%
scatter(data_iras['F100'], data_iras['F60'])
plt.title('IRIS Data Scatter Plot')
plt.xlabel('F100'), plt.ylabel('F60')
# Out:
# (Text(0.5, 0, 'F100'), Text(0, 0.5, 'F60'))

# %%
scatter(data_akari.F140, data_akari.F90)
plt.title('Akari Data Scatter Plot')
plt.xlabel('F140'), plt.ylabel('F90')
# Out:
# (Text(0.5, 0, 'F140'), Text(0, 0.5, 'F90'))

# %%
scatter(data_wise.F22, data_wise.F12)
plt.title('WISE Data Scatter Plot')
plt.xlabel('F140'), plt.ylabel('F90')
# Out:
# (Text(0.5, 0, 'F140'), Text(0, 0.5, 'F90'))

# %% [markdown]
# ## CONTOUR PLOT

# %%
def Tricontour(X, Y, Data, title, colorbar_label, fontsize=16):
    fontsize=11
    plt.tricontour(X, Y, Data, levels = 8, linestyles = ['solid'], origin = 'lower', colors = 'k') #contour only plots boundary
    plt.tricontourf(X, Y, Data, cmap='nipy_spectral', levels=1200) # contourf plots color-filled contour
    plt.colorbar().set_label(label = colorbar_label, weight='bold', fontsize=fontsize)
    plt.title(title, weight='bold')
    plt.xlabel('RA (deg)', weight='bold',fontsize=fontsize)
    plt.ylabel('DEC (deg)', weight='bold', fontsize=fontsize)
#     plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
#     plt.yticks(fontweight = None,fontsize=fontsize,color='k')

# %%
# GD 61 PLOT
# plt.figure(figsize=(18,7))
# plt.subplot(121)
# plt.title('IRIS Tricontour 100 $\mu m$')
# Tricontour(data["RA.1"], data["DEC.1"], data.F100)
# plt.subplot(122)
# Tricontour(data.RA, data.DEC, data.F60)
# plt.title('IRIS Tricontour 60 $\mu m$')

# %%
# GD 61 PLOT
# plt.figure(figsize=(18,7))
# plt.subplot(121)
# plt.title('IRIS Tricontour 100 $\mu m$')
# Tricontour(data["RA.2"], data["DEC.2"], data.F90)
# plt.subplot(122)
# Tricontour(data["RA.3"], data["DEC.3"], data.F140)
# plt.title('IRIS Tricontour 60 $\mu m$')

# %%
plt.figure(figsize=(20,24))
label = 'Flux (MJy sr$^{-1})$'
fontsize=14
plt.subplot(321)
Tricontour(data_iras['RA'], data_iras['DEC'], data_iras.F60, 'IRIS 60 $\mu$m', label)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.subplot(322)
Tricontour(data_iras['RA1'], data_iras['DEC1'], data_iras.F100, 'IRIS 100 $\mu$m', label)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.subplot(323)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.F90, 'AKARI 90 $\mu$m', label)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')
plt.subplot(324)
Tricontour(data_akari['RA1'], data_akari['DEC1'], data_akari.F140, 'AKARI 140 $\mu$m', label)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.subplot(325)
Tricontour(data_wise.RA, data_wise.DEC, data_wise.F12, 'WISE 12 $\mu$m', label)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(326)
Tricontour(data_wise['RA1'], data_wise['DEC1'], data_wise.F22, 'WISE 22 $\mu$m', label)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.savefig(FIG_DIR+"flux.png")
# Out:
# Locator attempting to generate 1141 ticks ([0.48, ..., 34.67999999999999]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1154 ticks ([1.36, ..., 47.48]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1146 ticks ([0.6000000000000001, ..., 172.35000000000002]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1128 ticks ([423.5, ..., 705.25]), which exceeds Locator.MAXTICKS (1000).

# %% [markdown]
# ## HEXBIN CONTOUR

# %%
def HexBin(X, Y, Data):
    plt.hexbin(X, Y, Data, gridsize=8, cmap='nipy_spectral')
    plt.colorbar().set_label('Relative Flux density')
    plt.xlabel('RA (deg)'),plt.ylabel('DEC (deg)')

    
plt.figure(figsize=(18,7))
plt.subplot(121)
# plt.title('IRIS 60 $\mu m$ Color Map')
HexBin(data_iras.RA, data_iras.DEC, data_iras.F60)
plt.subplot(122)
plt.title('IRIS 100 $\mu m$ Color Map')
HexBin(data_iras.RA1, data_iras.DEC1, data_iras.F100)
plt.show()

# %%
plt.figure(figsize=(18,7))
plt.subplot(121)
plt.title('Akari-S Dust Color Map')
HexBin(data_akari['RA'], data_akari['DEC'], data_akari.F90)
plt.subplot(122)
plt.title('Akari-L Dust Color Map')
HexBin(data_akari['RA1'], data_akari['DEC1'], data_akari.F140)
plt.show()

# %% [markdown]
# ## SPECTRAL EMISSIVITY

# %%
beta_range = np.arange(0,3.1, 0.1)
def Emissivity(F1, F2, mode="iras"):
    Temp = []
    Beta = []
    coeff = -96
    if mode=="akari": coeff = -57
    elif mode=="wise": coeff = -545.13
    print(coeff)
    for i in beta_range:
        t = coeff/(np.log(F1/F2)*0.6**(3+i))
        Temp.append(t)
        Beta.append(i)
    Tavg = [np.mean(Temp[i]) for i in range(len(Temp))]
    Y_err = np.std(Tavg)/np.sqrt(len(Tavg))
    def fun(Tav, a, b):
        err = float(1)/(a+(b*Tav))
        return err
    yerr = np.std(Beta)/np.sqrt(len(Beta))
    model = np.poly1d(np.polyfit(Tavg, Beta, deg=2)) #polynomial
    y = p(Beta)
    plt.figure(figsize=(15,8))
    _, caps, _ = plt.errorbar(Beta, Tavg, Y_err, fmt='ok', capsize=3, label='Datapoints')

    plt.plot(Beta, y, label='Best Fit', lw=3, color='r')
    plt.xlabel('Spectral Emissivity (Beta)'), plt.ylabel('Average Temperature (Tavg)')
    plt.legend()

# %%
Emissivity(data_iras.F60, data_iras.F100, mode="iras")
plt.title('IRIS Data Spectral Emissivity')
# Out:
# -96
# Text(0.5, 1.0, 'IRIS Data Spectral Emissivity')

# %%
Emissivity(data_akari.F90, data_akari.F140, "akari")
plt.title('Akari Data Spectral Emissivity')
# Out:
# -57
# Text(0.5, 1.0, 'Akari Data Spectral Emissivity')

# %%
Emissivity(data_wise.F22, data_wise.F12, "wise")
plt.title('WISE Data Spectral Emissivity')
# Out:
# -545.13
# Text(0.5, 1.0, 'WISE Data Spectral Emissivity')

# %%
# Emissivity(data.F60, data.F100, mode="iras")
# plt.title('IRIS Data Spectral Emissivity')

# %%
# Emissivity(data.F90, data.F140, mode="akari")
# plt.title('IRIS Data Spectral Emissivity')

# %% [markdown]
# ## GAUSSIAN FIT

# %%
def gaussian(x, nbins, xlabel= 'Temp (K)', fontsize=30):
    mu = np.mean(x)
    sigma = np.std(x)
    n, bins, patches = plt.hist(x, nbins, density=True, color="white", linewidth=3, edgecolor='k')
    y = ((1/(np.sqrt(2 * np.pi) * sigma))*np.exp(-0.5 * (1/sigma*(bins - mu))**2))
    plt.plot(bins, y, lw=5)
    plt.xlabel(xlabel, fontsize=fontsize, weight='bold')
    plt.ylabel('Probability Density', fontsize=fontsize, weight='bold')
    plt.xticks(fontsize=fontsize, color = 'k')
    plt.yticks(fontsize=fontsize,color='k')
    plt.tight_layout()

# %%
num_bins = 40
fontsize=30
plt.figure(figsize=(45,12))
plt.subplot(131)
plt.title('IRIS', fontweight = 'bold', fontsize=fontsize)
# plt.xlim([23,34])
gaussian(data_iras.Temp, num_bins)

plt.subplot(132)
plt.title('AKARI', fontweight = 'bold', fontsize=fontsize)
# plt.xlim([13,29])
gaussian(data_akari.Temp, num_bins)

plt.subplot(133)
plt.title('WISE', fontweight = 'bold', fontsize=fontsize)
# plt.xlim([380,460])
gaussian(data_wise.Temp, num_bins)

# plt.savefig(FIG_DIR+"tempGaussian.png")

# %%
# num_bins = 30
# plt.figure(figsize=(20,10))
# plt.subplot(121)
# plt.title('IRIS Temperature Gaussian Fit')
# plt.xlabel('Temp (K)')
# plt.xlim([22, 25])
# plt.ylabel('Probability Density')
# gaussian(data.Temp_iras, num_bins)

# plt.subplot(122)
# plt.title('Akari Temperature Gaussian Fit')
# plt.xlabel('Temp (K)')
# plt.xlim([13, 17])
# plt.ylabel('Probability Density')
# gaussian(data.Temp_akari, num_bins)

# %% [markdown]
# ## DISTANCE CALCULATION BY PARALLAX METHOD

# %%
df = pd.read_csv(data_files[0])
df
# len(df.parallax)
# plt.hist(df.parallax)
# df['parallax'].isnull().sum() #check for NaN
# Out:
#            ra        dec  parallax  parallax_error       pmra  pmra_error  \
# 0    3.880416 -39.105591       NaN             NaN        NaN         NaN
# 1    3.889869 -39.109657       NaN             NaN        NaN         NaN
# 2    3.862303 -39.113697 -0.918054        0.706639   6.780842    0.455116
# 3    3.846709 -39.097859  2.696278        0.168577  -5.911173    0.117183
# 4    3.844418 -39.095362  0.872577        0.492576  -3.108436    0.322015
# ..        ...        ...       ...             ...        ...         ...
# 196  3.813667 -38.998929       NaN             NaN        NaN         NaN
# 197  3.796422 -38.975655  0.336105        0.046604   9.056116    0.034838
# 198  3.808063 -38.972023  2.840327        0.137142  32.864279    0.103598
# 199  3.789553 -38.975180  0.677072        0.230116  -0.409710    0.169023
# 200  3.791263 -38.965743  1.939645        0.525229  -3.692647    0.390771
#
#          pmdec  pmdec_error
# 0          NaN          NaN
# ...

# %%
df1 = df[(df.parallax > 0) & (df.parallax<2) & (df.parallax>0.5)] # select 0.5<parallax>10 i.e. 166.67pc<d<2kpc, 
# len(df1)
plt.hist(df1.parallax)
sd = np.std(df1.parallax)
mean = np.mean(df1.parallax)
Range = mean-sd, mean+sd     # select the parallax data within the Range
del df1
# Range

# %%
df = df[(df.parallax>Range[0]) & (df.parallax<Range[1])]
len(df)
# df['parallax'].isnull().sum() #check for NaN
# Out:
# 43

# %%
df_prlx = df[(df.parallax/df.parallax_error>5)] #remove data with relative error<5 i.e with error >20%
len(df_prlx)
# plt.hist(df_prlx.parallax)
# plt.figure(figsize=(10,10))
# gaussian(df_prlx.parallax, nbins=20)
# Out:
# 20

# %%
# plt.figure(figsize=(8,8))
# plt.plot(df_prlx.ra, df_prlx.dec, 'or')

# %%
plt.figure(figsize=(10,8))
Tricontour(df_prlx.ra, df_prlx.dec, 1000/df_prlx.parallax, "Distance", "parsec")
# Out:
# Locator attempting to generate 1112 ticks ([676.0, ..., 1564.8000000000002]), which exceeds Locator.MAXTICKS (1000).

# %%
Dis = 1000/np.mean(df_prlx.parallax)
Dis # mean distance in pc  1215.3308148458173 GD61
# Out:
# 979.4899287650741

# %%
# Dis = 1000/np.mean(df_prlx.parallax)
# Dis # mean distance in pc

# %% [markdown]
# ## MASS CALCULATION

# %%
c = 3.0E+8      # speed of light in vacuum
h = 6.62E-34    # Planck's constant
kB = 1.38E-23   # Boltzmann constant
lam_iras = 10.0E-3    # Long-Wavelength IRAS
lam_akari = 1.4E-4    # Long-Wavelength Akari
lam_wise = 2.2E-5

# %%
def Mass(lam, Temp, Dis, flux):
    def planck(lam):
        a = np.exp(h*c/(kB*lam*Temp))
        b = 1/(a-1)
        Bv = h*c*b/lam**3     # Planck distribution
        return Bv    
    Su = flux*5.288*10**-29   # Absolute Flux 
    D = Dis*3.0857*10**16     # D in Km, Dis in pc
    M = 0.4*Su*D**2/planck(lam)
    return M

# %%
M_iras = Mass(lam_iras, data_iras.Temp, Dis, data_iras.F100)
data_iras['Mass'] = M_iras
np.mean(M_iras/(2E+30))   #in solar mass
# Out:
# 0.010322711460363334

# %%
M_akari = Mass(lam_akari, data_akari.Temp, Dis, data_akari.F140)
data_akari['Mass'] = M_akari
np.mean(M_akari/(2E+30))   #in solar mass
# Out:
# 0.0005622649072889703

# %%
M_wise = Mass(lam_wise, data_wise.Temp, Dis, data_wise.F22)
data_wise['Mass'] = M_wise
np.mean(M_wise/(2E+30))
# Out:
# 2.637771519019735e-07

# %%
data_akari
# Out:
#           F90   x   y        RA        DEC      F140  x1  y1       RA1  \
# 0    0.762714   1  30  3.856797 -39.115224  3.066137   1  30  3.856797
# 1    1.286675   2  30  3.849064 -39.115231  2.553307   2  30  3.849064
# 2    1.758307   3  30  3.841331 -39.115238  2.927438   3  30  3.841331
# 3    1.834949   4  30  3.833598 -39.115244  3.635061   4  30  3.833598
# 4    1.411721   5  30  3.825865 -39.115250  4.300227   5  30  3.825865
# ..        ...  ..  ..       ...        ...       ...  ..  ..       ...
# 895  2.257539  26   1  3.663267 -39.289249  3.044896  26   1  3.663267
# 896  2.256902  27   1  3.655515 -39.289244  3.667239  27   1  3.655515
# 897  1.711771  28   1  3.647762 -39.289238  3.003741  28   1  3.647762
# 898  1.685992  29   1  3.640010 -39.289231  2.440917  29   1  3.640010
# 899  1.637724  30   1  3.632258 -39.289224  1.952804  30   1  3.632258
#
#           DEC1       Temp          Mass
# 0   -39.115224  14.447134  1.006509e+27
# ...

# %%
# min(data.Temp_akari)-max(data.Temp_akari)

# %%
data_iras.Temp.corr(data_iras.Mass)
# Out:
# 0.5312487519349014

# %%
plt.figure(figsize=(15,10))
label_flux = 'Flux (MJy sr$^{-1})$'
label_mass = 'Mass(Kg)'
label_temp = 'Temperature(K)'
fontsize=16

plt.subplot(221)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.F60, 'IRIS Flux Distribution(60$\mu$m)', label_flux)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(222)
Tricontour(data_iras.RA1, data_iras.DEC1, data_iras.F100, 'IRIS Flux Distribution(100$\mu$m)', label_flux)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.subplot(223)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Temp, 'IRIS Temperature Distribution', label_temp)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(224)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Mass, 'IRIS Mass Distribution', label_mass)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')


plt.tight_layout()
# plt.savefig(FIG_DIR+"massTempContour.png")
plt.show()
# Out:
# Locator attempting to generate 1141 ticks ([0.48, ..., 34.67999999999999]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1154 ticks ([1.36, ..., 47.48]), which exceeds Locator.MAXTICKS (1000).

# %%
plt.figure(figsize=(15,10))
label_flux = 'Flux (MJy sr$^{-1})$'
label_mass = 'Mass(Kg)'
label_temp = 'Temperature(K)'
fontsize=16

plt.subplot(221)
Tricontour(data_akari.RA, data_akari.DEC, data_akari.F90, 'AKARI Flux Distribution(90$\mu$m)', label_flux)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.subplot(222)
Tricontour(data_akari.RA1, data_akari.DEC1, data_akari.F140, 'AKARI Flux Distribution(140$\mu$m)', label_flux)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.subplot(223)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Temp, 'AKARI Temperature Distibution', label_temp)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.subplot(224)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Mass, 'AKARI Mass Distibution', label_mass)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.tight_layout()
# plt.savefig(FIG_DIR+"massTempContour.png")
plt.show()

# %%
plt.figure(figsize=(15,10))
label_flux = 'Flux (MJy sr$^{-1})$'
label_mass = 'Mass(Kg)'
label_temp = 'Temperature(K)'
fontsize=16

plt.subplot(221)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.F60, 'IRIS Flux Distribution(60$\mu$m)', label_flux)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(222)
Tricontour(data_iras.RA1, data_iras.DEC1, data_iras.F100, 'IRIS Flux Distribution(100$\mu$m)', label_flux)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.subplot(223)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Temp, 'IRIS Temperature Distribution', label_temp)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(224)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Mass, 'IRIS Mass Distribution', label_mass)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')


plt.tight_layout()
# plt.savefig(FIG_DIR+"massTempContour.png")
plt.show()

# %%
plt.figure(figsize=(18,18))
label1 = 'Mass(Kg)'
label2 = 'Temperature(K)'
fontsize=16

plt.subplot(221)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Mass, 'IRIS Mass Distribution', label1)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(222)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Temp, 'IRIS Temperature Distribution', label2)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.subplot(223)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Mass, 'Akari Mass Distibution', label1)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')
plt.subplot(224)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Temp, 'Akari Temperature Distibution', label2)
plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.subplot(325)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.Mass, 'WISE Mass Distibution', label1)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(326)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.Temp, 'WISE Temperature Distibution', label2)
plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.tight_layout()
# plt.savefig(FIG_DIR+"massTempContour.png")
plt.show()

# %% [markdown]
# ## All Contour Plots

# %%
plt.figure(figsize=(23,5))
label1 = 'Mass(Kg)'
label2 = 'Flux(MJysr$^{-1}$)'
label3 = 'Temperature(K)'

plt.subplot(141)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.F60,'IRIS 60$\mu$m Flux Distribution', label2)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(142)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.F100, 'IRIS 100$\mu$m Flux Distribution', label2)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(143)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Mass, 'IRIS Mass Distribution', label1)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(144)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Temp, 'IRIS Temperature Distribution', label3)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')


plt.tight_layout()
plt.savefig(FIG_DIR+"Contour-iris.png")
plt.show()
# Out:
# Locator attempting to generate 1141 ticks ([0.48, ..., 34.67999999999999]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1154 ticks ([1.36, ..., 47.48]), which exceeds Locator.MAXTICKS (1000).

# %%
plt.figure(figsize=(23,5))
label1 = 'Mass(Kg)'
label2 = 'Flux(MJysr$^{-1}$)'
label3 = 'Temperature(K)'


plt.subplot(141)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.F90,'Akari 90$\mu$m Flux Distibution', label2)
# plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')
plt.subplot(142)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.F140, 'Akari 140$\mu$m Flux Distibution', label2)
# plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')
plt.subplot(143)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Mass, 'Akari Mass Distibution', label1)
# plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')
plt.subplot(144)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Temp, 'Akari Temperature Distibution', label3)
# plt.xticks([3.65, 3.70, 3.75, 3.80, 3.85], fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks([-39.12, -39.16, -39.20, -39.24, -39.28], fontweight = None,fontsize=fontsize,color='k')

plt.tight_layout()
plt.savefig(FIG_DIR+"Contour-akari.png")
plt.show()
# Out:
# Locator attempting to generate 1146 ticks ([0.6000000000000001, ..., 172.35000000000002]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1141 ticks ([2.4e+25, ..., 9.143999999999999e+27]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1020 ticks ([13.32, ..., 28.605]), which exceeds Locator.MAXTICKS (1000).

# %%
plt.figure(figsize=(23,5))
label1 = 'Mass(Kg)'
label2 = 'Flux(MJysr$^{-1}$)'
label3 = 'Temperature(K)'

plt.subplot(141)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.F12,'WISE 12$\mu$m Flux Distibution', label2)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(142)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.F22, 'WISE 22$\mu$m Flux Distibution', label2)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(143)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.Mass, 'WISE Mass Distibution', label1)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')
plt.subplot(144)
Tricontour(data_wise['RA'], data_wise['DEC'], data_wise.Temp, 'WISE Temperature Distibution', label3)
# plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
# plt.yticks(fontweight = None,fontsize=fontsize,color='k')

plt.tight_layout()
plt.savefig(FIG_DIR+"Contour-wise.png")
plt.show()
# Out:
# Locator attempting to generate 1128 ticks ([423.5, ..., 705.25]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1120 ticks ([403.36, ..., 492.88]), which exceeds Locator.MAXTICKS (1000).

# %% [markdown]
# ## Gaussian Plots

# %%
plt.figure(figsize=(45,12))
fontsize=20
plt.subplot(131)
plt.title('IRIS', fontweight = 'bold', fontsize=fontsize)
# plt.xlim([0.8E29, 1.8E29])
gaussian(data_iras['Mass'], num_bins, xlabel='Mass(kg)')

plt.subplot(132)
plt.title('AKARI', fontweight = 'bold', fontsize=fontsize)
gaussian(data_akari['Mass'], num_bins, xlabel='Mass(kg)')

plt.subplot(133)
plt.title('WISE', fontweight = 'bold', fontsize=fontsize)
gaussian(data_wise['Mass'], num_bins, xlabel='Mass(kg)')

plt.savefig(FIG_DIR+"massGaussian.png")

# %%
plt.figure(figsize=(45,12))
fontsize=20
plt.subplot(131)
plt.title('IRIS', fontweight = 'bold', fontsize=fontsize)
# plt.xlim([0.8E29, 1.8E29])
gaussian(data_iras['Temp'], num_bins, xlabel='Mass(kg)')

plt.subplot(132)
plt.title('AKARI', fontweight = 'bold', fontsize=fontsize)
gaussian(data_akari['Temp'], num_bins, xlabel='Mass(kg)')

plt.subplot(133)
plt.title('WISE', fontweight = 'bold', fontsize=fontsize)
gaussian(data_wise['Temp'], num_bins, xlabel='Mass(kg)')

plt.savefig(FIG_DIR+"tempGaussian.png")

# %% [markdown]
# ## Visual Extinction

# %%
scale = 5.288e-29
def extinction(lam, Temp, flux):
    a = np.exp(h*c/(kB*lam*Temp))
    b = 1/(a-1)
    planck = h*c*b/lam**3
    f = flux*scale
    opt_depth = (f/planck)
    ext = 15.078*(1 - np.exp(-opt_depth/641.3))
    return ext

# %%
Av_akari = extinction(lam_akari, data_akari.Temp, data_akari.F140)
Av_iras = extinction(lam_iras, data_iras.Temp, data_iras.F100)
Av_wise = extinction(lam_wise, data_wise.Temp, data_wise.F22)
data_akari['Av'] = Av_akari
data_iras['Av'] = Av_iras
data_wise['Av'] = Av_wise
# data_wise

# %%
plt.figure(figsize=(18,12))
label1 = 'Mass(Kg)'
label2 = 'Temperature(K)'

plt.subplot(221)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Av, 'IRIS Visual Extinction Distribution', label1)
plt.subplot(222)
Tricontour(data_iras.RA, data_iras.DEC, data_iras.Temp, 'IRIS Temperature Distribution', label2)

plt.subplot(223)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Av, 'Akari Visual Extinction Distibution', label1)
plt.subplot(224)
Tricontour(data_akari['RA'], data_akari['DEC'], data_akari.Temp, 'Akari Temperature Distibution', label2)

plt.tight_layout()
# plt.savefig(FIG_DIR+"massTempContour.png")
plt.show()
# Out:
# Locator attempting to generate 1174 ticks ([1.5000000000000001e-15, ..., 5.880000000000001e-13]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1020 ticks ([13.32, ..., 28.605]), which exceeds Locator.MAXTICKS (1000).

# %%
plt.figure(figsize=(20,15))
plt.subplot(221)
plt.title('IRAS Visual Extinction Plot')
plt.xlabel("Visual Extinction")
plt.ylabel("Temperature")
plt.scatter(Av_iras, data_iras.Temp)

plt.subplot(222)
plt.title('AKARI Visual Extinction Plot')
plt.xlabel("Visual Extinction")
plt.ylabel("Temperature")
plt.scatter(Av_akari, data_akari.Temp)

# plt.subplot(223)
# plt.title('WISE Visual Extinction Plot')
# plt.xlabel("Visual Extinction")
# plt.ylabel("Temperature")
# plt.scatter(Av_wise, data_wise.Temp)

# %%
print(np.mean(Av_iras), np.mean(Av_akari))
# Out:
# 3.316567368564758e-12 2.0208003159135e-13

# %% [markdown]
# ## INCLINATION ANGLE

# %%
a_iras = Dis*((19.01/60)*np.pi/180)
b_iras = Dis*((9.64/60)*np.pi/180)
a_iras, b_iras
# Out:
# (5.416368565615011, 2.7466487623634253)

# %%
a_akari = Dis*((6.58/60)*np.pi/180)
b_akari = Dis*((3.05/60)*np.pi/180)
a_akari, b_akari
# Out:
# (1.8747872257625866, 0.8690123158929921)

# %%
a_wise = Dis*((3.62/60)*np.pi/180)
b_wise = Dis*((1.79/60)*np.pi/180)
a_wise, b_wise
# Out:
# (1.0314178962402072, 0.5100105067044118)

# %%
# size of cavity = 23.184pc x 11.97pc
def inclination(a, b):
    axial_ratio = b/a  # b/a
    int_flat = 0.23 # (for now) 
    ratio = (axial_ratio**2-int_flat**2)/(1-int_flat**2)
    inc_angle = np.arccos(np.sqrt(ratio))*180/np.pi   # in degrees
    return inc_angle

# %%
inc_iras = inclination(a_iras, b_iras)
inc_akari = inclination(a_akari, b_akari)
inc_wise = inclination(a_wise, b_wise)
inc_iras, inc_akari, inc_wise
# Out:
# (62.32908737243153, 65.57359085410958, 63.27002413134323)

# %% [markdown]
# major axis (a) = 1.093$^o$ = 23.184 pc
# minor axis (b) = 33.44' = 11.82pc (**For GD61**)

# %% [markdown]
# ## JEANS MASS

# %% [markdown]
# ### $\rho = (\frac{3}{4\pi})^{2/3} \frac{k_b T}{m_HGR^2}$
# ### $M_J =  (\frac{k_b T}{m_HG})^{3/2}\frac{1}{\rho^{1/2}} $
# #### $m_H$ = mass of Hydrogen

# %%
def Jeans_mass(T, a = a, b = b, M_H = 1.67e-27, G = 6.67e-11):
    R = (a+b)/4 *3.0857e16    #mean diameter = (a+b)/2 so mean Radius = (a+b)/4
    density = (3/(4*np.pi))**(2/3)*kB*T/(M_H*G*R**2)
    M_Jeans = (kB*T/(M_H*G))**(3/2)*1/np.sqrt(density)
    return M_Jeans

# %%
M_Jeans_iras = Jeans_mass(data_iras.Temp)
M_Jeans_akari = Jeans_mass(data_akari.Temp)
M_Jeans_wise = Jeans_mass(data_wise.Temp)
np.mean(M_Jeans_iras), np.mean(M_Jeans_akari), np.mean(M_Jeans_wise)
# Out:
# (3.54926304357126e+32, 2.421476225336282e+32, 3.981848849779597e+33)

# %%
MJiris = np.mean(M_Jeans_iras)/1.989e+30    
MJakari = np.mean(M_Jeans_akari)/1.989e+30   
MJwise = np.mean(M_Jeans_wise)/1.989e+30

# %%
MJiris, MJakari, MJwise
# Out:
# (178.4445974646184, 121.74339996663056, 2001.9350677624923)

# %% [markdown]
# ## PolyFit

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model

# %%
def polyfit(x, y, xLabel, yLabel, title="IRIS", degree=1, fontsize = 14):
    plt.figure(figsize = [7,5])
    mymodel = np.poly1d(np.polyfit(x, y,degree))
    myline = np.linspace(min(x), max(x), len(y))
    r2 = r2_score(y, mymodel(x))
    plt.plot(x, y,'.b', label = 'Data')
    plt.plot(myline, mymodel(myline),'-',color = 'r',lw =3, label = 'Best Fit Polynomial, r$^2$='+str(np.round(r2, 2)))
    plt.title(title, weight="bold")
    plt.xlabel(xLabel, weight = 'bold',fontsize=fontsize)
    plt.ylabel(yLabel, weight = 'bold',fontsize=fontsize)
    plt.xticks(fontweight = None,fontsize=fontsize, color = 'k')
    plt.yticks(fontweight = None,fontsize=fontsize,color='k')
    plt.legend(fontsize = 10, loc = 'upper left')
#     print(r2_score(y, mymodel(x)))

# %% [markdown]
# ### Flux vs Av

# %%
polyfit(data_iras.F100, data_iras.Av, "Flux 100 $\mu$m", "Visual Extinciton", degree=1)

# %%
polyfit(data_akari.F140, data_akari.Av, "Flux 140 $\mu$m", "Visual Extinciton", title="AKARI", degree=3)

# %% [markdown]
# ### Temp vs Av

# %%
polyfit(data_iras.Av, data_iras.Temp, "A$_v$(mag)", "Temperature(K)", degree=1)
plt.savefig(FIG_DIR+"iras_tempAv.png")

# %%
polyfit(data_akari.Av, data_akari.Temp, "A$_v$(mag)", "Temperature(K)", title="AKARI", degree=2)
plt.savefig(FIG_DIR+"akari_tempAv.png")

# %%
polyfit(data_iras.Mass, data_iras.Temp, "Mass", "Temp", degree=1)
# plt.savefig(FIG_DIR+"iras-massTempFit.png")

# %%
polyfit(data_akari.Mass, data_akari.Temp, "Mass(Kg)", "Temp(K)", title="AKARI", degree=2)
# plt.savefig(FIG_DIR+"akari-massTempFit.png")

# %%
polyfit(data_wise.Mass, data_wise.Temp, "Mass(Kg)", "Temp(K)", title="WISE", degree=2)
# plt.savefig(FIG_DIR+"wise-massTempFit.png")

# %% [markdown]
# ## Flux Relation

# %%
polyfit(data_iras.F60, data_iras.F100, "Flux at 60 $\mu$m (MJy sr$^{-1}$)", "Flux at 100 $\mu$m(MJy sr$^{-1}$)", degree=1)
plt.savefig(FIG_DIR+"iras-fluxFit.png")

# %%
polyfit(data_akari.F90, data_akari.F140, "Flux at 90 $\mu$m(MJy sr$^{-1}$)", "Flux at 140 $\mu$m(MJy sr$^{-1}$)", title="AKARI", degree=2)
plt.savefig(FIG_DIR+"akari-fluxFit.png")

# %%
polyfit(data_wise.F12, data_wise.F22, "Flux at 12 $\mu$m(MJy sr$^{-1}$)", "Flux at 22 $\mu$m(MJy sr$^{-1}$)", title="WISE", degree=1)
plt.savefig(FIG_DIR+"wise-fluxFit.png")
